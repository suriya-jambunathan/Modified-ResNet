# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class BasicBlock_(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock_, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet_(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet_, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
#       self.dropout = nn.Dropout(p = dropout_prob)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 128, num_blocks[3], stride=2)
        self.layer5 = self._make_layer(block, 64, num_blocks[4], stride=2)
        self.layer6 = self._make_layer(block, 128, num_blocks[5], stride=2)
        self.layer7 = self._make_layer(block, 256, num_blocks[6], stride=2)
        self.linear = nn.Linear(256*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        
        out = self.layer1(out)
#       out = self.dropout(out)
        
        out = self.layer2(out)
#       out = self.dropout(out)
        
        out = self.layer3(out)
#       out = self.dropout(out)
        
        out = self.layer4(out)
#       out = self.dropout(out)
        
        out = self.layer5(out)
#       out = self.dropout(out)
        
        out = self.layer6(out)
#       out = self.dropout(out)
        
        out = self.layer7(out)
#       out = self.dropout(out)
        
        #out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

model = ResNet_(BasicBlock_, [2, 2, 2, 2, 2, 1, 1])
num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Num Params: {num_params}\n")
# Out:
# Num Params: 4891338

# %%
model = ResNet_(BasicBlock_, [2, 2, 2, 2, 2, 1, 1])
num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Num Params: {num_params}\n")
# Out:
# Num Params: 4891338

# %%
def train_val(model, criterion, optimizer, train_loader, val_loader, device, scheduler = None, use_scheduler = True):
    model.train()
    train_loss = 0
    correct = 0
    count = 0
    total = 0
    for i, data in enumerate(train_loader, 0):
        image, label = data
        image = image.to(device)
        label = label.to(device)
    
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)

        train_loss += loss.item()

        pred = torch.max(output.data, 1)[1]
        cur_correct = (pred == label).sum().item()
        cur_loss = loss.item()

        loss.backward()

        optimizer.step()
        
        total += label.size(0)
        correct += cur_correct
        train_loss += cur_loss

    train_accuracy = correct/total
    train_loss = train_loss/len(train_loader)
    
    model.eval()
    valid_loss = 0
    correct = 0
    count = 0
    total = 0
    for i, data in enumerate(val_loader, 0):
        image, label = data
        image = image.to(device)
        label = label.to(device)
                
        output = model(image)
        loss = criterion(output, label)

        pred = torch.max(output.data, 1)[1]
        cur_correct = (pred == label).sum().item()
        cur_loss = loss.item()
            
        total += label.size(0)
        correct += cur_correct
        valid_loss += cur_loss

    valid_accuracy = correct/total
    valid_loss = valid_loss/len(val_loader)
    
    if use_scheduler:
        scheduler.step(valid_accuracy)

    return train_loss, train_accuracy, valid_loss, valid_accuracy

def test(model, criterion, dataloader, device):
    model.eval()
    test_loss = 0
    correct = 0
    count = 0
    total = 0
    for i, data in enumerate(dataloader, 0):
        image, label = data
        image = image.to(device)
        label = label.to(device)
                
        output = model(image)
        loss = criterion(output, label)

        pred = torch.max(output.data, 1)[1]
        cur_correct = (pred == label).sum().item()
        cur_loss = loss.item()
            
        total += label.size(0)
        correct += cur_correct
        test_loss += cur_loss

    accuracy = correct/total
    test_loss = test_loss/len(dataloader)

    return test_loss, accuracy

# %%
# !pip install wandb --upgrade
# Out:
# Requirement already satisfied: wandb in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.14.2)
# Requirement already satisfied: PyYAML in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wandb) (6.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wandb) (8.1.3)
# Requirement already satisfied: appdirs>=1.4.3 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wandb) (1.4.4)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wandb) (3.1.31)
# Requirement already satisfied: setproctitle in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wandb) (1.3.2)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wandb) (3.19.6)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wandb) (2.28.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wandb) (0.4.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wandb) (1.19.1)
# Requirement already satisfied: pathtools in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wandb) (0.1.2)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages (from wandb) (65.5.0)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wandb) (5.9.4)
# Requirement already satisfied: colorama in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from Click!=8.0.0,>=7.0->wandb) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3,>=2.0.0->wandb) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3,>=2.0.0->wandb) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\91797\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)

# %%
batch_size = 32
transform_train = torchvision.transforms.Compose([
  torchvision.transforms.RandomCrop(32, padding=4),
  torchvision.transforms.RandomHorizontalFlip(),
  torchvision.transforms.RandomResizedCrop(32, scale=(0.8, 1.0), ratio=(0.8, 1.2)),
  torchvision.transforms.ToTensor(),
  torchvision.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

transform_test = torchvision.transforms.Compose([
                  torchvision.transforms.ToTensor(), 
                  torchvision.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

trainset = torchvision.datasets.CIFAR10(root = './data', train = True, download = True, transform = transform_train)

# Split the train data into train and validation sets
train_size = int(0.8 * len(trainset))
val_size = len(trainset) - train_size
trainset, valset = torch.utils.data.random_split(trainset, [train_size, val_size])

testset = torchvision.datasets.CIFAR10(root = './data', train = False, download = True, transform = transform_test)

train_loader = torch.utils.data.DataLoader(trainset, batch_size = batch_size, shuffle = True)
val_loader   = torch.utils.data.DataLoader(valset, batch_size = batch_size, shuffle = True)
test_loader  = torch.utils.data.DataLoader(testset, batch_size = batch_size, shuffle = False)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

best_test_acc = 0

torch.cuda.empty_cache()
model = ResNet_(BasicBlock_, [2, 2, 2, 2, 2, 1, 1])
num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Num Params: {num_params}\n")
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), 0.01, momentum = 0.7, weight_decay = 5e-4 , nesterov=True)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2, verbose = True)

train_losses_ = []
train_accuracies_ = []
valid_losses_ = []
valid_accuracies_ = []

epochs = 50

for epoch in range(epochs):
  print(f"\n\tEpoch: {epoch}")
  train_loss, train_accuracy, val_loss, val_accuracy = train_val(model, criterion, optimizer, 
                                                                train_loader, val_loader, device,
                                                                scheduler = scheduler, use_scheduler = True)
  train_losses_.append(train_loss)
  train_accuracies_.append(train_accuracy)
  valid_losses_.append(val_loss)
  valid_accuracies_.append(val_accuracy)
  print(f"\tTraining Loss: {round(train_loss, 4)}; Training Accuracy: {round(train_accuracy*100, 4)}%")
  print(f"\tValidation Loss: {round(val_loss, 4)}; Validation Accuracy: {round(val_accuracy*100, 4)}%")

test_loss, test_accuracy = test(model, criterion, test_loader, device)
print(f"\n\tTesting Loss: {round(test_loss, 4)}; Testing Accuracy: {round(test_accuracy*100, 4)}%")

if test_accuracy > best_test_acc:
  best_test_acc = test_accuracy

  torch.save(model.state_dict(), 'zigzag_resnet_7blocks.pth')

  metrics_dict = {'train_loss': train_losses_, 'train_accuracy': train_accuracies_, 
                  'valid_loss': valid_losses_, 'valid_accuracy': valid_accuracies_,
                  'test_loss': test_loss, 'test_accuracy': test_accuracy}
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Num Params: 4891338
#
#
# 	Epoch: 0
# 	Training Loss: 3.4881; Training Accuracy: 35.6175%
# 	Validation Loss: 1.4818; Validation Accuracy: 45.87%
#
# 	Epoch: 1
# 	Training Loss: 2.7003; Training Accuracy: 51.15%
# 	Validation Loss: 1.2147; Validation Accuracy: 55.56%
#
# 	Epoch: 2
# 	Training Loss: 2.2004; Training Accuracy: 60.7475%
# 	Validation Loss: 1.0514; Validation Accuracy: 63.2%
#
# 	Epoch: 3
# 	Training Loss: 1.8833; Training Accuracy: 67.245%
# 	Validation Loss: 1.0835; Validation Accuracy: 63.85%
#
# 	Epoch: 4
# 	Training Loss: 1.6546; Training Accuracy: 71.095%
# 	Validation Loss: 0.7849; Validation Accuracy: 73.32%
#
# 	Epoch: 5
# 	Training Loss: 1.5074; Training Accuracy: 74.1%
# 	Validation Loss: 0.7237; Validation Accuracy: 75.27%
#
# 	Epoch: 6
# 	Training Loss: 1.3774; Training Accuracy: 76.3025%
# 	Validation Loss: 0.6895; Validation Accuracy: 76.01%
#
# 	Epoch: 7
# 	Training Loss: 1.2776; Training Accuracy: 77.8875%
# 	Validation Loss: 0.6867; Validation Accuracy: 76.96%
#
# 	Epoch: 8
# 	Training Loss: 1.206; Training Accuracy: 79.3875%
# 	Validation Loss: 0.6531; Validation Accuracy: 77.54%
#
# 	Epoch: 9
# 	Training Loss: 1.1194; Training Accuracy: 80.91%
# 	Validation Loss: 0.6572; Validation Accuracy: 78.01%
#
# 	Epoch: 10
# 	Training Loss: 1.0631; Training Accuracy: 81.8825%
# 	Validation Loss: 0.5691; Validation Accuracy: 80.98%
#
# 	Epoch: 11
# 	Training Loss: 1.0077; Training Accuracy: 82.5225%
# 	Validation Loss: 0.5258; Validation Accuracy: 82.05%
#
# 	Epoch: 12
# 	Training Loss: 0.9565; Training Accuracy: 83.6225%
# 	Validation Loss: 0.5535; Validation Accuracy: 81.23%
#
# 	Epoch: 13
# 	Training Loss: 0.9086; Training Accuracy: 84.54%
# 	Validation Loss: 0.5146; Validation Accuracy: 82.45%
#
# 	Epoch: 14
# 	Training Loss: 0.8718; Training Accuracy: 85.1625%
# 	Validation Loss: 0.4764; Validation Accuracy: 83.78%
#
# 	Epoch: 15
# 	Training Loss: 0.8453; Training Accuracy: 85.5475%
# 	Validation Loss: 0.4614; Validation Accuracy: 84.42%
#
# 	Epoch: 16
# 	Training Loss: 0.8013; Training Accuracy: 86.1475%
# 	Validation Loss: 0.4689; Validation Accuracy: 83.96%
#
# 	Epoch: 17
# 	Training Loss: 0.7798; Training Accuracy: 86.645%
# 	Validation Loss: 0.5309; Validation Accuracy: 82.07%
#
# 	Epoch: 18
# 	Training Loss: 0.7302; Training Accuracy: 87.5975%
# 	Validation Loss: 0.451; Validation Accuracy: 84.63%
#
# 	Epoch: 19
# 	Training Loss: 0.7146; Training Accuracy: 87.84%
# 	Validation Loss: 0.4715; Validation Accuracy: 83.92%
#
# 	Epoch: 20
# 	Training Loss: 0.6804; Training Accuracy: 88.31%
# 	Validation Loss: 0.4606; Validation Accuracy: 84.64%
#
# 	Epoch: 21
# 	Training Loss: 0.667; Training Accuracy: 88.6%
# 	Validation Loss: 0.4585; Validation Accuracy: 84.65%
#
# 	Epoch: 22
# 	Training Loss: 0.6461; Training Accuracy: 88.9075%
# 	Validation Loss: 0.4085; Validation Accuracy: 86.22%
#
# 	Epoch: 23
# 	Training Loss: 0.6272; Training Accuracy: 89.28%
# 	Validation Loss: 0.4058; Validation Accuracy: 86.5%
#
# 	Epoch: 24
# 	Training Loss: 0.6129; Training Accuracy: 89.6%
# 	Validation Loss: 0.4349; Validation Accuracy: 85.06%
#
# 	Epoch: 25
# 	Training Loss: 0.5891; Training Accuracy: 89.915%
# 	Validation Loss: 0.4123; Validation Accuracy: 86.42%
#
# 	Epoch: 26
# 	Training Loss: 0.5576; Training Accuracy: 90.425%
# 	Validation Loss: 0.3876; Validation Accuracy: 87.25%
#
# 	Epoch: 27
# 	Training Loss: 0.5513; Training Accuracy: 90.575%
# 	Validation Loss: 0.394; Validation Accuracy: 86.52%
#
# 	Epoch: 28
# 	Training Loss: 0.5368; Training Accuracy: 90.86%
# 	Validation Loss: 0.3666; Validation Accuracy: 88.03%
#
# 	Epoch: 29
# 	Training Loss: 0.5236; Training Accuracy: 90.9975%
# 	Validation Loss: 0.4147; Validation Accuracy: 86.43%
#
# 	Epoch: 30
# 	Training Loss: 0.5083; Training Accuracy: 91.34%
# 	Validation Loss: 0.4043; Validation Accuracy: 86.63%
#
# 	Epoch: 31
# Epoch 00032: reducing learning rate of group 0 to 5.0000e-03.
# 	Training Loss: 0.4953; Training Accuracy: 91.685%
# 	Validation Loss: 0.4462; Validation Accuracy: 85.44%
#
# 	Epoch: 32
# 	Training Loss: 0.3475; Training Accuracy: 94.09%
# 	Validation Loss: 0.3351; Validation Accuracy: 89.08%
#
# 	Epoch: 33
# 	Training Loss: 0.3155; Training Accuracy: 94.745%
# 	Validation Loss: 0.3237; Validation Accuracy: 89.16%
#
# 	Epoch: 34
# 	Training Loss: 0.2998; Training Accuracy: 94.815%
# 	Validation Loss: 0.323; Validation Accuracy: 89.34%
#
# 	Epoch: 35
# 	Training Loss: 0.2933; Training Accuracy: 94.8975%
# 	Validation Loss: 0.3362; Validation Accuracy: 89.72%
#
# 	Epoch: 36
# 	Training Loss: 0.2781; Training Accuracy: 95.2375%
# 	Validation Loss: 0.3524; Validation Accuracy: 88.77%
#
# 	Epoch: 37
# 	Training Loss: 0.2717; Training Accuracy: 95.4%
# 	Validation Loss: 0.3463; Validation Accuracy: 89.12%
#
# 	Epoch: 38
# Epoch 00039: reducing learning rate of group 0 to 2.5000e-03.
# 	Training Loss: 0.2777; Training Accuracy: 95.21%
# 	Validation Loss: 0.3341; Validation Accuracy: 89.16%
#
# 	Epoch: 39
# 	Training Loss: 0.1932; Training Accuracy: 96.66%
# 	Validation Loss: 0.3081; Validation Accuracy: 90.23%
#
# 	Epoch: 40
# 	Training Loss: 0.1703; Training Accuracy: 97.065%
# 	Validation Loss: 0.3126; Validation Accuracy: 90.6%
#
# 	Epoch: 41
# 	Training Loss: 0.1614; Training Accuracy: 97.2675%
# 	Validation Loss: 0.3094; Validation Accuracy: 90.55%
#
# 	Epoch: 42
# 	Training Loss: 0.1529; Training Accuracy: 97.3175%
# 	Validation Loss: 0.3111; Validation Accuracy: 90.59%
#
# 	Epoch: 43
# 	Training Loss: 0.1509; Training Accuracy: 97.49%
# 	Validation Loss: 0.2972; Validation Accuracy: 91.15%
#
# 	Epoch: 44
# 	Training Loss: 0.1486; Training Accuracy: 97.4725%
# 	Validation Loss: 0.3232; Validation Accuracy: 90.45%
#
# 	Epoch: 45
# 	Training Loss: 0.1431; Training Accuracy: 97.58%
# 	Validation Loss: 0.3307; Validation Accuracy: 90.5%
#
# 	Epoch: 46
# Epoch 00047: reducing learning rate of group 0 to 1.2500e-03.
# 	Training Loss: 0.1358; Training Accuracy: 97.7225%
# 	Validation Loss: 0.3244; Validation Accuracy: 90.58%
#
# 	Epoch: 47
# 	Training Loss: 0.1103; Training Accuracy: 98.1575%
# 	Validation Loss: 0.3002; Validation Accuracy: 90.93%
#
# 	Epoch: 48
# 	Training Loss: 0.0996; Training Accuracy: 98.3125%
# 	Validation Loss: 0.2967; Validation Accuracy: 91.02%
#
# 	Epoch: 49
# Epoch 00050: reducing learning rate of group 0 to 6.2500e-04.
# 	Training Loss: 0.0947; Training Accuracy: 98.375%
# 	Validation Loss: 0.3062; Validation Accuracy: 91.15%
#
# 	Testing Loss: 0.2915; Testing Accuracy: 91.71%

# %%
for epoch in range(epochs):
  print(f"\n\tEpoch: {epoch + 50}")
  train_loss, train_accuracy, val_loss, val_accuracy = train_val(model, criterion, optimizer, 
                                                                train_loader, val_loader, device,
                                                                scheduler = scheduler, use_scheduler = True)
  train_losses_.append(train_loss)
  train_accuracies_.append(train_accuracy)
  valid_losses_.append(val_loss)
  valid_accuracies_.append(val_accuracy)
  print(f"\tTraining Loss: {round(train_loss, 4)}; Training Accuracy: {round(train_accuracy*100, 4)}%")
  print(f"\tValidation Loss: {round(val_loss, 4)}; Validation Accuracy: {round(val_accuracy*100, 4)}%")

test_loss, test_accuracy = test(model, criterion, test_loader, device)
print(f"\n\tTesting Loss: {round(test_loss, 4)}; Testing Accuracy: {round(test_accuracy*100, 4)}%")

if test_accuracy > best_test_acc:
  best_test_acc = test_accuracy

  torch.save(model.state_dict(), 'zigzag_resnet_7blocks.pth')

  metrics_dict = {'train_loss': train_losses_, 'train_accuracy': train_accuracies_, 
                  'valid_loss': valid_losses_, 'valid_accuracy': valid_accuracies_,
                  'test_loss': test_loss, 'test_accuracy': test_accuracy}
# Out:
# 	Epoch: 50
# 	Training Loss: 0.0821; Training Accuracy: 98.65%
# 	Validation Loss: 0.2985; Validation Accuracy: 91.3%
#
# 	Epoch: 51
# 	Training Loss: 0.0736; Training Accuracy: 98.82%
# 	Validation Loss: 0.2951; Validation Accuracy: 91.5%
#
# 	Epoch: 52
# 	Training Loss: 0.0727; Training Accuracy: 98.8175%
# 	Validation Loss: 0.3084; Validation Accuracy: 91.51%
#
# 	Epoch: 53
# 	Training Loss: 0.0729; Training Accuracy: 98.835%
# 	Validation Loss: 0.3069; Validation Accuracy: 91.33%
#
# 	Epoch: 54
# 	Training Loss: 0.0643; Training Accuracy: 98.945%
# 	Validation Loss: 0.3072; Validation Accuracy: 91.16%
#
# 	Epoch: 55
# Epoch 00056: reducing learning rate of group 0 to 3.1250e-04.
# 	Training Loss: 0.0683; Training Accuracy: 98.8725%
# 	Validation Loss: 0.3114; Validation Accuracy: 91.47%
#
# 	Epoch: 56
# 	Training Loss: 0.0635; Training Accuracy: 98.91%
# 	Validation Loss: 0.3057; Validation Accuracy: 91.39%
#
# 	Epoch: 57
# 	Training Loss: 0.0555; Training Accuracy: 99.1475%
# 	Validation Loss: 0.3114; Validation Accuracy: 91.18%
#
# 	Epoch: 58
# 	Training Loss: 0.0571; Training Accuracy: 99.14%
# 	Validation Loss: 0.3034; Validation Accuracy: 91.9%
#
# 	Epoch: 59
# 	Training Loss: 0.0567; Training Accuracy: 99.1025%
# 	Validation Loss: 0.3092; Validation Accuracy: 91.79%
#
# 	Epoch: 60
# 	Training Loss: 0.0486; Training Accuracy: 99.225%
# 	Validation Loss: 0.3167; Validation Accuracy: 91.54%
#
# 	Epoch: 61
# Epoch 00062: reducing learning rate of group 0 to 1.5625e-04.
# 	Training Loss: 0.0507; Training Accuracy: 99.165%
# 	Validation Loss: 0.3197; Validation Accuracy: 91.4%
#
# 	Epoch: 62
# 	Training Loss: 0.0532; Training Accuracy: 99.1475%
# 	Validation Loss: 0.3118; Validation Accuracy: 91.56%
#
# 	Epoch: 63
# 	Training Loss: 0.0531; Training Accuracy: 99.1325%
# 	Validation Loss: 0.3141; Validation Accuracy: 91.55%
#
# 	Epoch: 64
# 	Training Loss: 0.051; Training Accuracy: 99.2175%
# 	Validation Loss: 0.2957; Validation Accuracy: 91.98%
#
# 	Epoch: 65
# 	Training Loss: 0.0516; Training Accuracy: 99.1925%
# 	Validation Loss: 0.3125; Validation Accuracy: 91.69%
#
# 	Epoch: 66
# 	Training Loss: 0.0513; Training Accuracy: 99.2025%
# 	Validation Loss: 0.3076; Validation Accuracy: 91.99%
#
# 	Epoch: 67
# 	Training Loss: 0.0494; Training Accuracy: 99.21%
# 	Validation Loss: 0.3095; Validation Accuracy: 91.65%
#
# 	Epoch: 68
# 	Training Loss: 0.0512; Training Accuracy: 99.18%
# 	Validation Loss: 0.3099; Validation Accuracy: 91.55%
#
# 	Epoch: 69
# Epoch 00070: reducing learning rate of group 0 to 7.8125e-05.
# 	Training Loss: 0.0475; Training Accuracy: 99.25%
# 	Validation Loss: 0.3142; Validation Accuracy: 91.64%
#
# 	Epoch: 70
# 	Training Loss: 0.0432; Training Accuracy: 99.3025%
# 	Validation Loss: 0.3126; Validation Accuracy: 91.79%
#
# 	Epoch: 71
# 	Training Loss: 0.0483; Training Accuracy: 99.195%
# 	Validation Loss: 0.3118; Validation Accuracy: 91.75%
#
# 	Epoch: 72
# Epoch 00073: reducing learning rate of group 0 to 3.9063e-05.
# 	Training Loss: 0.0472; Training Accuracy: 99.24%
# 	Validation Loss: 0.3146; Validation Accuracy: 91.29%
#
# 	Epoch: 73
# 	Training Loss: 0.0476; Training Accuracy: 99.265%
# 	Validation Loss: 0.3231; Validation Accuracy: 91.51%
#
# 	Epoch: 74
# 	Training Loss: 0.05; Training Accuracy: 99.21%
# 	Validation Loss: 0.3161; Validation Accuracy: 91.73%
#
# 	Epoch: 75
# Epoch 00076: reducing learning rate of group 0 to 1.9531e-05.
# 	Training Loss: 0.0468; Training Accuracy: 99.29%
# 	Validation Loss: 0.3074; Validation Accuracy: 91.82%
#
# 	Epoch: 76
# 	Training Loss: 0.0495; Training Accuracy: 99.195%
# 	Validation Loss: 0.3029; Validation Accuracy: 91.81%
#
# 	Epoch: 77
# 	Training Loss: 0.0472; Training Accuracy: 99.2225%
# 	Validation Loss: 0.3131; Validation Accuracy: 91.9%
#
# 	Epoch: 78
# Epoch 00079: reducing learning rate of group 0 to 9.7656e-06.
# 	Training Loss: 0.044; Training Accuracy: 99.31%
# 	Validation Loss: 0.3128; Validation Accuracy: 91.62%
#
# 	Epoch: 79
# 	Training Loss: 0.0422; Training Accuracy: 99.3425%
# 	Validation Loss: 0.2937; Validation Accuracy: 92.13%
#
# 	Epoch: 80
# 	Training Loss: 0.0439; Training Accuracy: 99.3025%
# 	Validation Loss: 0.309; Validation Accuracy: 91.43%
#
# 	Epoch: 81
# 	Training Loss: 0.0461; Training Accuracy: 99.2725%
# 	Validation Loss: 0.3062; Validation Accuracy: 91.89%
#
# 	Epoch: 82
# Epoch 00083: reducing learning rate of group 0 to 4.8828e-06.
# 	Training Loss: 0.0452; Training Accuracy: 99.2825%
# 	Validation Loss: 0.3133; Validation Accuracy: 91.69%
#
# 	Epoch: 83
# 	Training Loss: 0.0484; Training Accuracy: 99.2375%
# 	Validation Loss: 0.3188; Validation Accuracy: 91.2%
#
# 	Epoch: 84
# 	Training Loss: 0.046; Training Accuracy: 99.22%
# 	Validation Loss: 0.3073; Validation Accuracy: 91.84%
#
# 	Epoch: 85
# Epoch 00086: reducing learning rate of group 0 to 2.4414e-06.
# 	Training Loss: 0.0454; Training Accuracy: 99.3025%
# 	Validation Loss: 0.3013; Validation Accuracy: 92.13%
#
# 	Epoch: 86
# 	Training Loss: 0.0456; Training Accuracy: 99.2575%
# 	Validation Loss: 0.3028; Validation Accuracy: 91.89%
#
# 	Epoch: 87
# 	Training Loss: 0.0463; Training Accuracy: 99.2975%
# 	Validation Loss: 0.3124; Validation Accuracy: 91.61%
#
# 	Epoch: 88
# Epoch 00089: reducing learning rate of group 0 to 1.2207e-06.
# 	Training Loss: 0.046; Training Accuracy: 99.2675%
# 	Validation Loss: 0.319; Validation Accuracy: 91.56%
#
# 	Epoch: 89
# 	Training Loss: 0.0429; Training Accuracy: 99.34%
# 	Validation Loss: 0.3135; Validation Accuracy: 91.88%
#
# 	Epoch: 90
# 	Training Loss: 0.0464; Training Accuracy: 99.2625%
# 	Validation Loss: 0.3048; Validation Accuracy: 91.72%
#
# 	Epoch: 91
# Epoch 00092: reducing learning rate of group 0 to 6.1035e-07.
# 	Training Loss: 0.0461; Training Accuracy: 99.2775%
# 	Validation Loss: 0.301; Validation Accuracy: 92.07%
#
# 	Epoch: 92
# 	Training Loss: 0.041; Training Accuracy: 99.3725%
# 	Validation Loss: 0.3145; Validation Accuracy: 91.75%
#
# 	Epoch: 93
# 	Training Loss: 0.0435; Training Accuracy: 99.3125%
# 	Validation Loss: 0.3051; Validation Accuracy: 91.84%
#
# 	Epoch: 94
# Epoch 00095: reducing learning rate of group 0 to 3.0518e-07.
# 	Training Loss: 0.0463; Training Accuracy: 99.29%
# 	Validation Loss: 0.3043; Validation Accuracy: 91.88%
#
# 	Epoch: 95
# 	Training Loss: 0.0471; Training Accuracy: 99.2425%
# 	Validation Loss: 0.3186; Validation Accuracy: 91.41%
#
# 	Epoch: 96
# 	Training Loss: 0.0476; Training Accuracy: 99.23%
# 	Validation Loss: 0.3128; Validation Accuracy: 91.47%
#
# 	Epoch: 97
# Epoch 00098: reducing learning rate of group 0 to 1.5259e-07.
# 	Training Loss: 0.044; Training Accuracy: 99.2675%
# 	Validation Loss: 0.3101; Validation Accuracy: 91.9%
#
# 	Epoch: 98
# 	Training Loss: 0.0479; Training Accuracy: 99.275%
# 	Validation Loss: 0.3125; Validation Accuracy: 91.66%
#
# 	Epoch: 99
# 	Training Loss: 0.0448; Training Accuracy: 99.3075%
# 	Validation Loss: 0.3052; Validation Accuracy: 91.74%
#
# 	Testing Loss: 0.2911; Testing Accuracy: 92.18%
